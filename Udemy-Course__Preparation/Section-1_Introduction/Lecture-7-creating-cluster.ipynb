# %% [markdown]
# # Lecture 7. Creating Cluster

# %% [markdown]
# ## What to Note
#
# - A *cluster* is a set of nodes or computers working together like a single entity.
#   - It consists of a master node called the *driver* and some other *worker* nodes.
#   The driver node is responsible for coordinating the workers and their parallel execution of tasks.
#
#   - Your cluster could be multi node, that is having multiple workers, or simply a single node.
#   A single node cluster, has no workers and run Spark jobs on the driver node.
#
# - *Databricks Runtime* is the virtual machine's image that comes with preinstalled libraries,
# which has a specific version of Spark, Scala and other libraries.
#
# - *Photon* is a vectorized query engine developed in C++ to enhance Spark performance.
#
# - *DBU* stands for Databricks Unit and it is a unit of a processing capability per hour.

# %% [markdown]
# ## Hands-on
#
# - Navigate to **Compute** in the left side bar. Under All-purpose compute tab, click **Create compute**.
#
#   <div style="text-align: center;">
#   <img src="../../assets/images/Screen-Captures/Compute none.jpg" style="width:1280px" >
#   </div>
#
# - "New compute" page
#   - Multi node: Overview
#     <div style="text-align: center;">
#     <img src="../../assets/images/Screen-Captures/Compute - New compute - multi node.jpg" style="width:1280px" >
#     </div>
#
#   - Single node: Create
#     <div style="text-align: center;">
#     <img src="../../assets/images/Screen-Captures/Compute - New compute - single node.jpg" style="width:1280px" >
#     </div>
#
#     | Item | Setting |
#     | -- | -- |
#     | Cluster name | **Demo Cluster** |
#     | Cluster mode | **Signle node** |
#     | Runtime version | 13.3 LTS |
#     | Use Photon Acceleration | Uncheck |
#     | Node type | Standard_DS3_v2 (4 cores) |
#     | Auto termination | 30 minutes |
#
#   Click "Create compute".
#     Azure will now go ahead and provision the required virtual machine with a specific configuration and libraries as specified by Databricks runtime.
#
#     Our cluster now is up and running.
#
#     <div style="text-align: center;">
#     <img src="../../assets/images/Screen-Captures/Compute - Demo Cluster running.jpg" style="width:1280px" >
#     </div>
#
# - To access your cluster at any time, you can simply navigate to Compute in the left side bar.
#   - You can see your clusters are listed here with its current status running or terminated.
#     <div style="text-align: center;">
#     <img src="../../assets/images/Screen-Captures/Compute - listed.jpg" style="width:1280px" >
#     </div>
#
#     From here, you can quickly terminate or start your cluster.
#
#   - In addition to deleting the cluster and editing its permissions, you can even edit the cluster by clicking on its name. Then click Edit.
#
#     <div style="text-align: center;">
#     <img src="../../assets/images/Screen-Captures/Compute - Demo Cluster running.jpg" style="width:1280px" >
#     </div>
#
#     <div style="text-align: center;">
#     <img src="../../assets/images/Screen-Captures/Compute - Cluster Edit.jpg" style="width:1280px" >
#     </div>
#
#     Remember, changing the cluster configuration may require a restart of the cluster.
#
#   - In the cluster page, you can notice two things.
#     * The *event log*, that shows all the events that have happened with the cluster.
#     For example, when the cluster was created or terminated, if it is edited or if it is running fine.
#     This helps to track the activity on a cluster.
#
#       <div style="text-align: center;">
#       <img src="../../assets/images/Screen-Captures/Compute - Cluster - Event log.jpg" style="width:1280px" >
#       </div>
#
#     * In the *driver logs*, you will get the log generated within the cluster notebooks and libraries.
#
#       <div style="text-align: center;">
#       <img src="../../assets/images/Screen-Captures/Compute - Cluster - Driver logs.jpg" style="width:1280px" >
#       </div>
#
# - Let's now terminate our cluster.

# %% [markdown]
# ## Databricks Official Documentation References
#
# - [Cluster](https://docs.databricks.com/en/getting-started/concepts.html#cluster)
# - [Compute](https://docs.databricks.com/en/compute/index.html)
